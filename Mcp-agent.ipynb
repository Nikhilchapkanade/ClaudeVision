# %%
# Cell 1: Install ComfyUI and Ngrok
# !git clone https://github.com/comfyanonymous/ComfyUI
# %cd ComfyUI
# !pip install -r requirements.txt
# !pip install pyngrok

# Download a standard model (v1.5) so it works out of the box
# !wget -c https://huggingface.co/runwayml/stable-diffusion-v1-5/resolve/main/v1-5-pruned-emaonly.ckpt -P ./models/checkpoints/

print("Installation Complete!")
# Out:
# Cloning into 'ComfyUI'...
# remote: Enumerating objects: 30911, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 30911 (delta 86), reused 46 (delta 46), pack-reused 30777 (from 4)
# Receiving objects: 100% (30911/30911), 77.17 MiB | 24.11 MiB/s, done.
# Resolving deltas: 100% (20930/20930), done.
# /content/ComfyUI
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.9/19.9 MB 125.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 151.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.4/43.4 kB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.1/78.1 MB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.2/15.2 MB 132.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 MB 15.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.4/65.4 MB 12.8 MB/s eta 0:00:00
# ...

# %%
# Cell 2: Start the Server
from pyngrok import ngrok
import os

# --- PASTE YOUR TOKEN BELOW ---
NGROK_TOKEN = "PASTE_YOUR_NGROK_TOKEN_HERE"
# ------------------------------

ngrok.set_auth_token(NGROK_TOKEN)
# Open a tunnel to port 8188 (ComfyUI default)
public_url = ngrok.connect(8188).public_url
print(f"YOUR CLOUD URL IS: {public_url}")

# Start ComfyUI
# !python main.py --listen
# Out:
# YOUR CLOUD URL IS: https://unexcursive-reprovable-christi.ngrok-free.dev
# Checkpoint files will always be loaded safely.
# WARNING: You need pytorch with cu130 or higher to use optimized CUDA operations.
# Found comfy_kitchen backend cuda: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'scaled_mm_nvfp4']}
# Found comfy_kitchen backend eager: {'available': True, 'disabled': False, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8', 'scaled_mm_nvfp4']}
# Found comfy_kitchen backend triton: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8']}
# ...
